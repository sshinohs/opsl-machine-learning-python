# %%
import import_ipynb
import motion as mt
import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
# Out:
# importing Jupyter notebook from motion.ipynb

# %%
dir_path = 'data/motion'

# %%
rao_path_list = mt.path_rao(dir_path)

# %%
decay_path_list = mt.path_decay(dir_path)

# %%
damping_path_list = mt.path_damping(dir_path)

# %%
data = mt.load_rao(rao_path_list[0])

# %%
data
# Out:
#       frame   time       trx       try       trz       tpx       tpy  \
# 0         0   0.00 -0.010862  0.012480 -0.038738  0.004480 -0.225415
# 1         1   0.01 -0.010830  0.012312 -0.038801  0.004472 -0.225418
# 2         2   0.02 -0.008581  0.005036 -0.039099  0.004466 -0.225421
# 3         3   0.03 -0.008581  0.005036 -0.039099  0.004466 -0.225421
# 4         4   0.04 -0.008921  0.004794 -0.039140  0.004464 -0.225424
# ...     ...    ...       ...       ...       ...       ...       ...
# 6100   6100  61.00  0.000463  0.009014 -0.052688  0.004882 -0.227127
# 6101   6101  61.01  0.019783  0.022636 -0.102313  0.005057 -0.226954
# 6102   6102  61.02  0.007368  0.029105 -0.142381  0.005280 -0.226776
# 6103   6103  61.03  0.009980  0.022014 -0.181468  0.005499 -0.226576
# 6104   6104  61.04 -0.002642  0.028265 -0.222345  0.005713 -0.226379
#
#            tpz       mme       px1  ...       py3       pz3       px4  \
# ...

# %%
plt.figure(figsize=(12,7))
plt.plot(data.time, data.trx)
plt.grid(True)
plt.xlabel('Time(s)')
plt.ylabel('X')
plt.show()
